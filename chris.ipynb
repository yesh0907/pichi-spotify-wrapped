# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_json("data/sarah/Playlist1.json")
df
# Out:
#                                             playlists
# 0   {'name': 'baking a cake with miyamura', 'lastM...
# 1   {'name': 'driving west on the 60 fwy', 'lastMo...
# 2   {'name': 'lucky #3', 'lastModifiedDate': '2021...
# 3   {'name': 'rasengan training', 'lastModifiedDat...
# 4   {'name': 'kindex ii', 'lastModifiedDate': '202...
# 5   {'name': 'sparks', 'lastModifiedDate': '2021-0...
# 6   {'name': '(twenty)^2', 'lastModifiedDate': '20...
# 7   {'name': 'peachy 🥀 ', 'lastModifiedDate': '202...
# 8   {'name': 'oof', 'lastModifiedDate': '2020-04-1...
# 9   {'name': 'heat', 'lastModifiedDate': '2020-04-...
# 10  {'name': 'chill', 'lastModifiedDate': '2020-04...
# 11  {'name': 'breezy', 'lastModifiedDate': '2020-0...
# 12  {'name': 'kindex', 'lastModifiedDate': '2020-0...
# 13  {'name': 'index', 'lastModifiedDate': '2021-04...
# 14  {'name': '🦑', 'lastModifiedDate': '2018-08-23'...
# 15  {'name': '우을증', 'lastModifiedDate': '2019-03-2...
# ...

# %%
df.lo
# Out:
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Float',
#     'artistName': '6LACK',
#     'albumName': '6pc Hot EP'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Lonely (with benny blanco)',
#     'artistName': 'Justin Bieber',
#     'albumName': 'Lonely (with benny blanco)'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'Outside',
#     'artistName': '6LACK',
#     'albumName': '6pc Hot EP'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'she likes spring, I prefer winter',
#     'artistName': 'slchld',
#     'albumName': 'my insecurities, not yours'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'off the table (with The Weeknd)',
#     'artistName': 'Ariana Grande',
#     'albumName': 'Positions'},
#    'episode': None,
#    'localTrack': None},
#   {'track': {'trackName': 'my hair',
#     'artistName': 'Ariana Grande',
# ...
